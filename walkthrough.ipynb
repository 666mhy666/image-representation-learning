# %% [markdown]
# # Comparing PCA, Autoencoders, and VAEs
#
# A short executable entry point for the revised analysis. See README.md for data access, methods, and limitations. Outputs are intentionally cleared in version control.

# %%
# Run from the repository root after placing authorized data locally.
# %run analysis.py --images /path/to/authorized/images --limit 10000 --epochs 10 --output results
