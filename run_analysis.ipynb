# %% [markdown]
# # Run Comparing PCA, Autoencoders, and VAEs
#
# This notebook is a convenient launcher for the revised command-line analysis. Read README.md and DATA_ACCESS.md before running it. Outputs are intentionally cleared in version control.

# %%
# Run from the repository root after placing authorized data locally.
# %run analysis.py --images /path/to/authorized/images --limit 10000 --epochs 10 --output results
